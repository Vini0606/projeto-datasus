# %%
import os
import sys

# Adicionar o diretório raiz do projeto ao path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from src.analysis.univariate_analyzer import UnivariateAnalyzer
from src.analysis.data_quality import DataQualityAuditor

# 1. Obter dados
auditor = DataQualityAuditor(os.getenv("DB_URL"))
df = auditor.fetch_data()

# 2. Instanciar Analisador
univariada = UnivariateAnalyzer(df)

# %% [markdown]
# ### Análise da Variável: Valor Aprovado

# %%
display(univariada.get_summary_statistics('valor_aprovado'))
univariada.plot_distribution('valor_aprovado')
univariada.plot_outliers('valor_aprovado')
# Out:
# Média                 8.805659e+03
# Mediana               0.000000e+00
# Moda                  0.000000e+00
# Desvio Padrão         1.423866e+05
# Variância             2.027395e+10
# Coef. Variação (%)    1.616990e+03
# Assimetria            5.708585e+01
# Curtose               5.594585e+03
# dtype: float64

# %% [markdown]
# ### Análise da Variável: Subgrupo de Procedimento

# %%
univariada.analyze_categorical('subgrupo_procedimento')
# Out:
# c:\Projetos\projeto-datasus-sia\src\analysis\univariate_analyzer.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=freq.values, y=freq.index, palette="viridis")
# subgrupo_procedimento
# Município                                                   91007
# 0101 Acoes coletivas/individuais em saude                   91007
# 0102 Vigilancia em saude                                    91007
# 0201 Coleta de material                                     91007
# 0202 Diagnostico em laboratorio clinico                     91007
# 0204 Diagnostico por radiologia                             91007
# 0203 Diagnostico por anatomia patologica e citopatologia    91007
# 0205 Diagnostico por ultrasonografia                        91007
# 0206 Diagnostico por tomografia                             91007
# ...
